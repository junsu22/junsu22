# %%
# API KEY를 환경변수로 관리하기 위한 설정 파일
from dotenv import load_dotenv

# API KEY 정보로드
load_dotenv()
# Out:
# True

# %% [markdown]
# ## 실습에 활용한 문서
#
# 소프트웨어정책연구소(SPRi) - 2023년 12월호
#
# - 저자: 유재흥(AI정책연구실 책임연구원), 이지수(AI정책연구실 위촉연구원)
# - 링크: https://spri.kr/posts/view/23669
# - 파일명: `SPRI_AI_Brief_2023년12월호_F.pdf`

# %%
FILE_PATH = "./data/SPRI_AI_Brief_2023년12월호_F.pdf"

# %%
def show_metadata(docs):
    if docs:
        print("[metadata]")
        print(list(docs[0].metadata.keys()))
        print("\n[examples]")
        max_key_length = max(len(k) for k in docs[0].metadata.keys())
        for k, v in docs[0].metadata.items():
            print(f"{k:<{max_key_length}} : {v}")

# %% [markdown]
# ## PyPDF
#
# 여기에서는 `pypdf`를 사용하여 PDF를 문서 배열로 로드하며, 각 문서는 `page` 번호와 함께 페이지 내용 및 메타데이터를 포함합니다.

# %%
# 설치
# !pip install -qU pypdf

# %%
# !pip install langchain-community pypdf
# Out:
# Requirement already satisfied: langchain-community in c:\ai\envs\ai\lib\site-packages (0.4.1)
# Requirement already satisfied: pypdf in c:\ai\envs\ai\lib\site-packages (6.9.2)
# Requirement already satisfied: langchain-core<2.0.0,>=1.0.1 in c:\ai\envs\ai\lib\site-packages (from langchain-community) (1.2.26)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.0 in c:\ai\envs\ai\lib\site-packages (from langchain-community) (1.0.3)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in c:\ai\envs\ai\lib\site-packages (from langchain-community) (2.0.49)
# Requirement already satisfied: requests<3.0.0,>=2.32.5 in c:\ai\envs\ai\lib\site-packages (from langchain-community) (2.32.5)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in c:\ai\envs\ai\lib\site-packages (from langchain-community) (6.0.3)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\ai\envs\ai\lib\site-packages (from langchain-community) (3.13.5)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\ai\envs\ai\lib\site-packages (from langchain-community) (9.1.4)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in c:\ai\envs\ai\lib\site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in c:\ai\envs\ai\lib\site-packages (from langchain-community) (2.13.1)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in c:\ai\envs\ai\lib\site-packages (from langchain-community) (0.7.26)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in c:\ai\envs\ai\lib\site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: numpy>=1.26.2 in c:\ai\envs\ai\lib\site-packages (from langchain-community) (2.1.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\ai\envs\ai\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\ai\envs\ai\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in c:\ai\envs\ai\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (4.0.3)
# Requirement already satisfied: attrs>=17.3.0 in c:\ai\envs\ai\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\ai\envs\ai\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\ai\envs\ai\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in c:\ai\envs\ai\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\ai\envs\ai\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.23.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\ai\envs\ai\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (3.26.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\ai\envs\ai\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.1 in c:\ai\envs\ai\lib\site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain-community) (1.1.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\ai\envs\ai\lib\site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain-community) (2.12.5)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\ai\envs\ai\lib\site-packages (from langchain-core<2.0.0,>=1.0.1->langchain-community) (1.33)
# Requirement already satisfied: packaging>=23.2.0 in c:\ai\envs\ai\lib\site-packages (from langchain-core<2.0.0,>=1.0.1->langchain-community) (25.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\ai\envs\ai\lib\site-packages (from langchain-core<2.0.0,>=1.0.1->langchain-community) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\ai\envs\ai\lib\site-packages (from langchain-core<2.0.0,>=1.0.1->langchain-community) (0.14.1)
# Requirement already satisfied: jsonpointer>=1.9 in c:\ai\envs\ai\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.0.1->langchain-community) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\ai\envs\ai\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\ai\envs\ai\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (3.11.7)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\ai\envs\ai\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: xxhash>=3.0.0 in c:\ai\envs\ai\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (3.6.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\ai\envs\ai\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.25.0)
# Requirement already satisfied: anyio in c:\ai\envs\ai\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (4.12.1)
# Requirement already satisfied: certifi in c:\ai\envs\ai\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in c:\ai\envs\ai\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.9)
# Requirement already satisfied: idna in c:\ai\envs\ai\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\ai\envs\ai\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\ai\envs\ai\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain-community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\ai\envs\ai\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain-community) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\ai\envs\ai\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain-community) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\ai\envs\ai\lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.2.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\ai\envs\ai\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\ai\envs\ai\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2.6.3)
# Requirement already satisfied: greenlet>=1 in c:\ai\envs\ai\lib\site-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain-community) (3.3.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\ai\envs\ai\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community) (1.1.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\ai\envs\ai\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (1.3.1)
# WARNING: Ignoring invalid distribution -ensorflow (c:\ai\envs\ai\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (c:\ai\envs\ai\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (c:\ai\envs\ai\lib\site-packages)

# %%
from langchain_community.document_loaders import PyPDFLoader

# 파일 경로 설정

FILE_PATH = "./data/SPRI_AI_Brief_2023년12월호_F.pdf"
loader = PyPDFLoader(FILE_PATH)

# PDF 로더 초기화
docs = loader.load()

# 문서의 내용 출력
print(docs[10].page_content[:300])
# Out:
# c:\AI\envs\ai\lib\site-packages\transformers\utils\generic.py:441: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   _torch_pytree._register_pytree_node(
# SPRi AI Brief |  2023-12월호
# 8
# 코히어, 데이터 투명성 확보를 위한 데이터 출처 탐색기 공개n코히어와 12개 기관이  광범위한 데이터셋에 대한 감사를 통해 원본 데이터 출처, 재라이선스 상태, 작성자 등 다양한 정보를 제공하는 ‘데이터 출처 탐색기’ 플랫폼을 출시n대화형 플랫폼을 통해 개발자는 데이터셋의 라이선스 상태를 쉽게 파악할 수 있으며 데이터셋의 구성과 계보도 추적 가능
# KEY Contents
# £데이터 출처 탐색기, 광범위한 데이터셋 정보 제공을 통해 데이터 투명성 향상nAI 기업 코히어(Cohere)가

# %%
# 메타데이터 출력
show_metadata(docs)
# Out:
# [metadata]
# ['producer', 'creator', 'creationdate', 'author', 'moddate', 'pdfversion', 'source', 'total_pages', 'page', 'page_label']
#
# [examples]
# producer     : Hancom PDF 1.3.0.542
# creator      : Hwp 2018 10.0.0.13462
# creationdate : 2023-12-08T13:28:38+09:00
# author       : dj
# moddate      : 2023-12-08T13:28:38+09:00
# pdfversion   : 1.4
# source       : ./data/SPRI_AI_Brief_2023년12월호_F.pdf
# total_pages  : 23
# page         : 0
# page_label   : 1

# %% [markdown]
# ### PyPDF(OCR)

# %% [markdown]
# 일부 PDF에는 스캔된 문서나 그림 내에 텍스트 이미지가 포함되어 있습니다. `rapidocr-onnxruntime` 패키지를 사용하여 이미지에서 텍스트를 추출할 수도 있습니다.

# %%
# 설치
# !pip install -qU rapidocr-onnxruntime
# Out:
# WARNING: Ignoring invalid distribution -ensorflow (c:\ai\envs\ai\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (c:\ai\envs\ai\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (c:\ai\envs\ai\lib\site-packages)

# %%
# PDF 로더 초기화, 이미지 추출 옵션 활성화
loader = PyPDFLoader("https://arxiv.org/pdf/2103.15348.pdf", extract_images=True)

# PDF 페이지 로드
docs = loader.load()

# 페이지 내용 접근
print(docs[4].page_content[:300])
# Out:
# LayoutParser: A Uniﬁed Toolkit for DL-Based DIA 5
# Table 1: Current layout detection models in the LayoutParser model zoo
# Dataset Base Model1 Large ModelNotes
# PubLayNet [38] F / M M Layouts of modern scientiﬁc documents
# PRImA [3] M - Layouts of scanned modern magazines and scientiﬁc reports
# Newspaper

# %%
show_metadata(docs)
# Out:
# [metadata]
# ['producer', 'creator', 'creationdate', 'author', 'keywords', 'moddate', 'ptex.fullbanner', 'subject', 'title', 'trapped', 'source', 'total_pages', 'page', 'page_label']
#
# [examples]
# producer        : pdfTeX-1.40.21
# creator         : LaTeX with hyperref
# creationdate    : 2021-06-22T01:27:10+00:00
# author          :
# keywords        :
# moddate         : 2021-06-22T01:27:10+00:00
# ptex.fullbanner : This is pdfTeX, Version 3.14159265-2.6-1.40.21 (TeX Live 2020) kpathsea version 6.3.2
# subject         :
# title           :
# trapped         : /False
# source          : https://arxiv.org/pdf/2103.15348.pdf
# total_pages     : 16
# page            : 0
# page_label      : 1

# %% [markdown]
# ## PyMuPDF

# %% [markdown]
# **PyMuPDF** 는 속도 최적화가 되어 있으며, PDF 및 해당 페이지에 대한 자세한 메타데이터를 포함하고 있습니다. 페이지 당 하나의 문서를 반환합니다:

# %%
# 설치
# !pip install -qU pymupdf
# Out:
# WARNING: Ignoring invalid distribution -ensorflow (c:\ai\envs\ai\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (c:\ai\envs\ai\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (c:\ai\envs\ai\lib\site-packages)

# %%
from langchain_community.document_loaders import PyMuPDFLoader

# PyMuPDF 로더 인스턴스 생성
loader = PyMuPDFLoader(FILE_PATH)

# 문서 로드
docs = loader.load()

# 문서의 내용 출력
print(docs[10].page_content[:300])
# Out:
# SPRi AI Brief |
# 2023-12월호
# 8
# 코히어, 데이터 투명성 확보를 위한 데이터 출처 탐색기 공개
# n 코히어와 12개 기관이  광범위한 데이터셋에 대한 감사를 통해 원본 데이터 출처, 재라이선스 상태,
# 작성자 등 다양한 정보를 제공하는 ‘데이터 출처 탐색기’ 플랫폼을 출시
# n 대화형 플랫폼을 통해 개발자는 데이터셋의 라이선스 상태를 쉽게 파악할 수 있으며 데이터셋의
# 구성과 계보도 추적 가능
# KEY Contents
# £ 데이터 출처 탐색기, 광범위한 데이터셋 정보 제공을 통해 데이터 투명성 향상
# n AI 기업 코히어

# %%
show_metadata(docs)
# Out:
# [metadata]
# ['producer', 'creator', 'creationdate', 'source', 'file_path', 'total_pages', 'format', 'title', 'author', 'subject', 'keywords', 'moddate', 'trapped', 'modDate', 'creationDate', 'page']
#
# [examples]
# producer     : Hancom PDF 1.3.0.542
# creator      : Hwp 2018 10.0.0.13462
# creationdate : 2023-12-08T13:28:38+09:00
# source       : ./data/SPRI_AI_Brief_2023년12월호_F.pdf
# file_path    : ./data/SPRI_AI_Brief_2023년12월호_F.pdf
# total_pages  : 23
# format       : PDF 1.4
# title        :
# author       : dj
# subject      :
# keywords     :
# moddate      : 2023-12-08T13:28:38+09:00
# trapped      :
# modDate      : D:20231208132838+09'00'
# creationDate : D:20231208132838+09'00'
# page         : 0

# %% [markdown]
# ## Unstructured

# %% [markdown]
# [Unstructured](https://unstructured-io.github.io/unstructured/)는 Markdown이나 PDF와 같은 비구조화된 또는 반구조화된 파일 형식을 다루기 위한 공통 인터페이스를 지원합니다.
#
# LangChain의 [UnstructuredPDFLoader](https://api.python.langchain.com/en/latest/document_loaders/langchain_community.document_loaders.pdf.UnstructuredPDFLoader.html)는 Unstructured와 통합되어 PDF 문서를 LangChain [Document](https://api.python.langchain.com/en/latest/documents/langchain_core.documents.base.Document.html) 객체로 파싱합니다.

# %%
# 설치
# !pip install -qU unstructured
# Out:
# WARNING: Ignoring invalid distribution -ensorflow (c:\ai\envs\ai\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (c:\ai\envs\ai\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (c:\ai\envs\ai\lib\site-packages)

# %%
# !pip install pdfminer.six
# Out:
# Requirement already satisfied: pdfminer.six in c:\ai\envs\ai\lib\site-packages (20260107)
# Requirement already satisfied: charset-normalizer>=2.0.0 in c:\ai\envs\ai\lib\site-packages (from pdfminer.six) (3.4.4)
# Requirement already satisfied: cryptography>=36.0.0 in c:\ai\envs\ai\lib\site-packages (from pdfminer.six) (46.0.5)
# Requirement already satisfied: cffi>=2.0.0 in c:\ai\envs\ai\lib\site-packages (from cryptography>=36.0.0->pdfminer.six) (2.0.0)
# Requirement already satisfied: typing-extensions>=4.13.2 in c:\ai\envs\ai\lib\site-packages (from cryptography>=36.0.0->pdfminer.six) (4.15.0)
# Requirement already satisfied: pycparser in c:\ai\envs\ai\lib\site-packages (from cffi>=2.0.0->cryptography>=36.0.0->pdfminer.six) (3.0)
# WARNING: Ignoring invalid distribution -ensorflow (c:\ai\envs\ai\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (c:\ai\envs\ai\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (c:\ai\envs\ai\lib\site-packages)

# %%
# !pip install pi-heif
# Out:
# Requirement already satisfied: pi-heif in c:\ai\envs\ai\lib\site-packages (1.3.0)
# Requirement already satisfied: pillow>=11.1.0 in c:\ai\envs\ai\lib\site-packages (from pi-heif) (12.1.1)
# WARNING: Ignoring invalid distribution -ensorflow (c:\ai\envs\ai\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (c:\ai\envs\ai\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (c:\ai\envs\ai\lib\site-packages)

# %%
# !pip install unstructured-inference
# Out:
# Requirement already satisfied: unstructured-inference in c:\ai\envs\ai\lib\site-packages (1.2.0)
# Requirement already satisfied: python-multipart in c:\ai\envs\ai\lib\site-packages (from unstructured-inference) (0.0.24)
# Requirement already satisfied: huggingface-hub in c:\ai\envs\ai\lib\site-packages (from unstructured-inference) (0.17.3)
# Requirement already satisfied: numpy in c:\ai\envs\ai\lib\site-packages (from unstructured-inference) (2.1.3)
# Requirement already satisfied: opencv-python>=4.13.0.90 in c:\ai\envs\ai\lib\site-packages (from unstructured-inference) (4.13.0.92)
# Requirement already satisfied: onnx in c:\ai\envs\ai\lib\site-packages (from unstructured-inference) (1.21.0)
# Requirement already satisfied: onnxruntime>=1.18.0 in c:\ai\envs\ai\lib\site-packages (from unstructured-inference) (1.23.2)
# Requirement already satisfied: matplotlib in c:\ai\envs\ai\lib\site-packages (from unstructured-inference) (3.10.8)
# Requirement already satisfied: torch in c:\ai\envs\ai\lib\site-packages (from unstructured-inference) (2.5.1+cu121)
# Requirement already satisfied: timm in c:\ai\envs\ai\lib\site-packages (from unstructured-inference) (1.0.26)
# Requirement already satisfied: transformers>=4.25.1 in c:\ai\envs\ai\lib\site-packages (from unstructured-inference) (4.35.0)
# Requirement already satisfied: accelerate in c:\ai\envs\ai\lib\site-packages (from unstructured-inference) (0.31.0)
# Requirement already satisfied: rapidfuzz in c:\ai\envs\ai\lib\site-packages (from unstructured-inference) (3.14.4)
# Requirement already satisfied: pandas in c:\ai\envs\ai\lib\site-packages (from unstructured-inference) (2.3.3)
# Requirement already satisfied: scipy in c:\ai\envs\ai\lib\site-packages (from unstructured-inference) (1.15.3)
# Requirement already satisfied: pypdfium2>=5.0.0 in c:\ai\envs\ai\lib\site-packages (from unstructured-inference) (5.6.0)
# Requirement already satisfied: pdfminer-six in c:\ai\envs\ai\lib\site-packages (from unstructured-inference) (20260107)
# Requirement already satisfied: coloredlogs in c:\ai\envs\ai\lib\site-packages (from onnxruntime>=1.18.0->unstructured-inference) (15.0.1)
# Requirement already satisfied: flatbuffers in c:\ai\envs\ai\lib\site-packages (from onnxruntime>=1.18.0->unstructured-inference) (25.12.19)
# Requirement already satisfied: packaging in c:\ai\envs\ai\lib\site-packages (from onnxruntime>=1.18.0->unstructured-inference) (25.0)
# Requirement already satisfied: protobuf in c:\ai\envs\ai\lib\site-packages (from onnxruntime>=1.18.0->unstructured-inference) (7.34.1)
# Requirement already satisfied: sympy in c:\ai\envs\ai\lib\site-packages (from onnxruntime>=1.18.0->unstructured-inference) (1.13.1)
# Requirement already satisfied: filelock in c:\ai\envs\ai\lib\site-packages (from transformers>=4.25.1->unstructured-inference) (3.24.3)
# Requirement already satisfied: pyyaml>=5.1 in c:\ai\envs\ai\lib\site-packages (from transformers>=4.25.1->unstructured-inference) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in c:\ai\envs\ai\lib\site-packages (from transformers>=4.25.1->unstructured-inference) (2026.2.28)
# Requirement already satisfied: requests in c:\ai\envs\ai\lib\site-packages (from transformers>=4.25.1->unstructured-inference) (2.32.5)
# Requirement already satisfied: tokenizers<0.15,>=0.14 in c:\ai\envs\ai\lib\site-packages (from transformers>=4.25.1->unstructured-inference) (0.14.1)
# Requirement already satisfied: safetensors>=0.3.1 in c:\ai\envs\ai\lib\site-packages (from transformers>=4.25.1->unstructured-inference) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in c:\ai\envs\ai\lib\site-packages (from transformers>=4.25.1->unstructured-inference) (4.67.3)
# Requirement already satisfied: fsspec in c:\ai\envs\ai\lib\site-packages (from huggingface-hub->unstructured-inference) (2026.2.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\ai\envs\ai\lib\site-packages (from huggingface-hub->unstructured-inference) (4.15.0)
# Requirement already satisfied: colorama in c:\ai\envs\ai\lib\site-packages (from tqdm>=4.27->transformers>=4.25.1->unstructured-inference) (0.4.6)
# Requirement already satisfied: psutil in c:\ai\envs\ai\lib\site-packages (from accelerate->unstructured-inference) (7.2.2)
# Requirement already satisfied: networkx in c:\ai\envs\ai\lib\site-packages (from torch->unstructured-inference) (3.4.2)
# Requirement already satisfied: jinja2 in c:\ai\envs\ai\lib\site-packages (from torch->unstructured-inference) (3.1.6)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\ai\envs\ai\lib\site-packages (from sympy->onnxruntime>=1.18.0->unstructured-inference) (1.3.0)
# Requirement already satisfied: humanfriendly>=9.1 in c:\ai\envs\ai\lib\site-packages (from coloredlogs->onnxruntime>=1.18.0->unstructured-inference) (10.0)
# Requirement already satisfied: pyreadline3 in c:\ai\envs\ai\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.18.0->unstructured-inference) (3.5.4)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\ai\envs\ai\lib\site-packages (from jinja2->torch->unstructured-inference) (3.0.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\ai\envs\ai\lib\site-packages (from matplotlib->unstructured-inference) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\ai\envs\ai\lib\site-packages (from matplotlib->unstructured-inference) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\ai\envs\ai\lib\site-packages (from matplotlib->unstructured-inference) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\ai\envs\ai\lib\site-packages (from matplotlib->unstructured-inference) (1.4.9)
# Requirement already satisfied: pillow>=8 in c:\ai\envs\ai\lib\site-packages (from matplotlib->unstructured-inference) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in c:\ai\envs\ai\lib\site-packages (from matplotlib->unstructured-inference) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\ai\envs\ai\lib\site-packages (from matplotlib->unstructured-inference) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\ai\envs\ai\lib\site-packages (from python-dateutil>=2.7->matplotlib->unstructured-inference) (1.17.0)
# Requirement already satisfied: ml_dtypes>=0.5.0 in c:\ai\envs\ai\lib\site-packages (from onnx->unstructured-inference) (0.5.4)
# Requirement already satisfied: pytz>=2020.1 in c:\ai\envs\ai\lib\site-packages (from pandas->unstructured-inference) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\ai\envs\ai\lib\site-packages (from pandas->unstructured-inference) (2025.3)
# Requirement already satisfied: charset-normalizer>=2.0.0 in c:\ai\envs\ai\lib\site-packages (from pdfminer-six->unstructured-inference) (3.4.4)
# Requirement already satisfied: cryptography>=36.0.0 in c:\ai\envs\ai\lib\site-packages (from pdfminer-six->unstructured-inference) (46.0.5)
# Requirement already satisfied: cffi>=2.0.0 in c:\ai\envs\ai\lib\site-packages (from cryptography>=36.0.0->pdfminer-six->unstructured-inference) (2.0.0)
# Requirement already satisfied: pycparser in c:\ai\envs\ai\lib\site-packages (from cffi>=2.0.0->cryptography>=36.0.0->pdfminer-six->unstructured-inference) (3.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\ai\envs\ai\lib\site-packages (from requests->transformers>=4.25.1->unstructured-inference) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\ai\envs\ai\lib\site-packages (from requests->transformers>=4.25.1->unstructured-inference) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\ai\envs\ai\lib\site-packages (from requests->transformers>=4.25.1->unstructured-inference) (2026.2.25)
# Requirement already satisfied: torchvision in c:\ai\envs\ai\lib\site-packages (from timm->unstructured-inference) (0.20.1+cu121)
# WARNING: Ignoring invalid distribution -ensorflow (c:\ai\envs\ai\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (c:\ai\envs\ai\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (c:\ai\envs\ai\lib\site-packages)

# %%
# !pip install unstructured-pytesseract
# Out:
# Requirement already satisfied: unstructured-pytesseract in c:\ai\envs\ai\lib\site-packages (0.3.15)
# Requirement already satisfied: packaging>=21.3 in c:\ai\envs\ai\lib\site-packages (from unstructured-pytesseract) (25.0)
# Requirement already satisfied: Pillow>=8.0.0 in c:\ai\envs\ai\lib\site-packages (from unstructured-pytesseract) (12.1.1)
# WARNING: Ignoring invalid distribution -ensorflow (c:\ai\envs\ai\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (c:\ai\envs\ai\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (c:\ai\envs\ai\lib\site-packages)

# %%
# 실행 보류: Tesseract OCR 환경이 없어 건너뜀
# from langchain_community.document_loaders import UnstructuredPDFLoader
# loader = UnstructuredPDFLoader(FILE_PATH)
# docs = loader.load()
# print(docs[0].page_content[:300])

# %%
# 실행 보류: UnstructuredPDFLoader 셀을 건너뛰어 metadata 확인도 건너뜀
# show_metadata(docs)

# %% [markdown]
# 내부적으로 비정형에서는 텍스트 청크마다 서로 다른 "**요소**"를 만듭니다. 기본적으로 이들은 결합되어 있지만 `mode="elements"`를 지정하여 쉽게 분리할 수 있습니다.

# %%
# 실행 보류: Tesseract OCR 환경이 없어 건너뜀
# loader = UnstructuredPDFLoader(FILE_PATH, mode="elements")
# docs = loader.load()
# print(docs[0].page_content)

# %% [markdown]
# 이 특정 문서에 대한 전체 요소 유형 집합을 참조하세요

# %%
# 실행 보류: UnstructuredPDFLoader 결과가 없어 category 확인도 건너뜀
# set(doc.metadata["category"] for doc in docs)

# %%
show_metadata(docs)
# Out:
# [metadata]
# ['producer', 'creator', 'creationdate', 'source', 'file_path', 'total_pages', 'format', 'title', 'author', 'subject', 'keywords', 'moddate', 'trapped', 'modDate', 'creationDate', 'page']
#
# [examples]
# producer     : Hancom PDF 1.3.0.542
# creator      : Hwp 2018 10.0.0.13462
# creationdate : 2023-12-08T13:28:38+09:00
# source       : ./data/SPRI_AI_Brief_2023년12월호_F.pdf
# file_path    : ./data/SPRI_AI_Brief_2023년12월호_F.pdf
# total_pages  : 23
# format       : PDF 1.4
# title        :
# author       : dj
# subject      :
# keywords     :
# moddate      : 2023-12-08T13:28:38+09:00
# trapped      :
# modDate      : D:20231208132838+09'00'
# creationDate : D:20231208132838+09'00'
# page         : 0

# %% [markdown]
# ## PyPDFium2

# %%
from langchain_community.document_loaders import PyPDFium2Loader

# PyPDFium2 로더 인스턴스 생성
loader = PyPDFium2Loader(FILE_PATH)

# 데이터 로드
docs = loader.load()

# 문서의 내용 출력
print(docs[10].page_content[:300])
# Out:
# SPRi AI Brief |
# 2023-12월호
# 8
# 코히어, 데이터 투명성 확보를 위한 데이터 출처 탐색기 공개
# n 코히어와 12개 기관이 광범위한 데이터셋에 대한 감사를 통해 원본 데이터 출처, 재라이선스 상태, 작성자 등 다양한 정보를 제공하는 ‘데이터 출처 탐색기’ 플랫폼을 출시
# n 대화형 플랫폼을 통해 개발자는 데이터셋의 라이선스 상태를 쉽게 파악할 수 있으며 데이터셋의
# 구성과 계보도 추적 가능
# KEY Contents
# £ 데이터 출처 탐색기, 광범위한 데이터셋 정보 제공을 통해 데이터 투명성 향상
# n AI 기업 코히어(Co

# %%
show_metadata(docs)
# Out:
# [metadata]
# ['producer', 'creator', 'creationdate', 'title', 'author', 'subject', 'keywords', 'moddate', 'source', 'total_pages', 'page']
#
# [examples]
# producer     : Hancom PDF 1.3.0.542
# creator      : Hwp 2018 10.0.0.13462
# creationdate : 2023-12-08T13:28:38+09:00
# title        :
# author       : dj
# subject      :
# keywords     :
# moddate      : 2023-12-08T13:28:38+09:00
# source       : ./data/SPRI_AI_Brief_2023년12월호_F.pdf
# total_pages  : 23
# page         : 0

# %% [markdown]
# ## PDFMiner

# %%
from langchain_community.document_loaders import PDFMinerLoader

# PDFMiner 로더 인스턴스 생성
loader = PDFMinerLoader(FILE_PATH)

# 데이터 로드
docs = loader.load()

# 문서의 내용 출력
print(docs[0].page_content[:300])
# Out:
# 2023년  12월호
# 2023년  12월호
#
# Ⅰ.  인공지능  산업  동향  브리프
#
#   1.  정책/법제
#
#       ▹  미국,  안전하고  신뢰할  수  있는  AI  개발과  사용에  관한  행정명령  발표    ························· 1
#
#       ▹  G7,  히로시마  AI  프로세스를  통해  AI  기업  대상  국제  행동강령에  합의 ··························· 2
#
#       ▹  영국  AI  안전성  정상회의에  참가한  28개국,  AI  위험에  공동

# %%
show_metadata(docs)
# Out:
# [metadata]
# ['producer', 'creator', 'creationdate', 'author', 'moddate', 'pdfversion', 'total_pages', 'source']
#
# [examples]
# producer     : Hancom PDF 1.3.0.542
# creator      : Hwp 2018 10.0.0.13462
# creationdate : 2023-12-08T13:28:38+09:00
# author       : dj
# moddate      : 2023-12-08T13:28:38+09:00
# pdfversion   : 1.4
# total_pages  : 23
# source       : ./data/SPRI_AI_Brief_2023년12월호_F.pdf

# %% [markdown]
# **PDFMiner**를 사용하여 HTML 텍스트 생성
#
# 이 방법은 출력된 HTML 콘텐츠를 `BeautifulSoup`을 통해 파싱함으로써 글꼴 크기, 페이지 번호, PDF 헤더/푸터 등에 대한 보다 구조화되고 풍부한 정보를 얻을 수 있게 하여 텍스트를 의미론적으로 섹션으로 분할하는 데 도움이 될 수 있습니다.

# %%
from langchain_community.document_loaders import PDFMinerPDFasHTMLLoader

# PDFMinerPDFasHTMLLoader 인스턴스 생성
loader = PDFMinerPDFasHTMLLoader(FILE_PATH)

# 문서 로드
docs = loader.load()

# 문서의 내용 출력
print(docs[0].page_content[:300])
# Out:
# <html><head>
# <meta http-equiv="Content-Type" content="text/html">
# </head><body>
# <span style="position:absolute; border: gray 1px solid; left:0.0px; top:50.0px; width:612.0px; height:858.0px;"></span>
# <div style="position:absolute; top:%dpx;">50.0<a name="1">Page 1</a></div>
# <div style="position:abso

# %%
show_metadata(docs)
# Out:
# [metadata]
# ['source']
#
# [examples]
# source : ./data/SPRI_AI_Brief_2023년12월호_F.pdf

# %%
from bs4 import BeautifulSoup

soup = BeautifulSoup(docs[0].page_content, "html.parser")  # HTML 파서 초기화
content = soup.find_all("div")  # 모든 div 태그 검색

# %%
import re

cur_fs = None
cur_text = ""
snippets = []  # 동일한 글꼴 크기의 모든 스니펫 수집
for c in content:
    sp = c.find("span")
    if not sp:
        continue
    st = sp.get("style")
    if not st:
        continue
    fs = re.findall("font-size:(\d+)px", st)
    if not fs:
        continue
    fs = int(fs[0])
    if not cur_fs:
        cur_fs = fs
    if fs == cur_fs:
        cur_text += c.text
    else:
        snippets.append((cur_text, cur_fs))
        cur_fs = fs
        cur_text = c.text
snippets.append((cur_text, cur_fs))
# 중복 스니펫 제거 전략 추가 가능성 (PDF의 헤더/푸터가 여러 페이지에 걸쳐 나타나므로 중복 발견 시 중복 정보로 간주 가능)

# %%
from langchain_core.documents import Document

cur_idx = -1
semantic_snippets = []
# 제목 가정: 높은 글꼴 크기
for s in snippets:
    # 새 제목 판별: 현재 스니펫 글꼴 > 이전 제목 글꼴
    if (
        not semantic_snippets
        or s[1] > semantic_snippets[cur_idx].metadata["heading_font"]
    ):
        metadata = {"heading": s[0], "content_font": 0, "heading_font": s[1]}
        metadata.update(docs[0].metadata)
        semantic_snippets.append(Document(page_content="", metadata=metadata))
        cur_idx += 1
        continue

    # 동일 섹션 내용 판별: 현재 스니펫 글꼴 <= 이전 내용 글꼴
    if (
        not semantic_snippets[cur_idx].metadata["content_font"]
        or s[1] <= semantic_snippets[cur_idx].metadata["content_font"]
    ):
        semantic_snippets[cur_idx].page_content += s[0]
        semantic_snippets[cur_idx].metadata["content_font"] = max(
            s[1], semantic_snippets[cur_idx].metadata["content_font"]
        )
        continue

    # 새 섹션 생성 조건: 현재 스니펫 글꼴 > 이전 내용 글꼴, 이전 제목 글꼴 미만
    metadata = {"heading": s[0], "content_font": 0, "heading_font": s[1]}
    metadata.update(docs[0].metadata)
    semantic_snippets.append(Document(page_content="", metadata=metadata))
    cur_idx += 1

print(semantic_snippets[0])
# Out:
# page_content='' metadata={'heading': '', 'content_font': 0, 'heading_font': None, 'source': './data/SPRI_AI_Brief_2023년12월호_F.pdf'}

# %% [markdown]
# ## PyPDF 디렉토리
#
# 디렉토리에서 PDF를 로드하세요

# %%
from langchain_community.document_loaders import PyPDFDirectoryLoader

# 디렉토리 경로
loader = PyPDFDirectoryLoader("data/")

# 문서 로드
docs = loader.load()

# 문서의 개수 출력
print(len(docs))
# Out:
# 23

# %%
# 문서의 내용 출력
print(docs[0].page_content[:300])
# Out:
# 2023년 12월호

# %%
# metadata 출력
print(docs[0].metadata)
# Out:
# {'producer': 'Hancom PDF 1.3.0.542', 'creator': 'Hwp 2018 10.0.0.13462', 'creationdate': '2023-12-08T13:28:38+09:00', 'author': 'dj', 'moddate': '2023-12-08T13:28:38+09:00', 'pdfversion': '1.4', 'source': 'data\\SPRI_AI_Brief_2023년12월호_F.pdf', 'total_pages': 23, 'page': 0, 'page_label': '1'}

# %% [markdown]
# ## PDFPlumber
#
# PyMuPDF와 마찬가지로, 출력 문서는 PDF와 그 페이지에 대한 자세한 메타데이터를 포함하며, 페이지 당 하나의 문서를 반환합니다.

# %%
# !pip install pdfplumber
# Out:
# Collecting pdfplumber
#   Downloading pdfplumber-0.11.9-py3-none-any.whl.metadata (43 kB)
# Collecting pdfminer.six==20251230 (from pdfplumber)
#   Downloading pdfminer_six-20251230-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: Pillow>=9.1 in c:\ai\envs\ai\lib\site-packages (from pdfplumber) (12.1.1)
# Requirement already satisfied: pypdfium2>=4.18.0 in c:\ai\envs\ai\lib\site-packages (from pdfplumber) (5.6.0)
# Requirement already satisfied: charset-normalizer>=2.0.0 in c:\ai\envs\ai\lib\site-packages (from pdfminer.six==20251230->pdfplumber) (3.4.4)
# Requirement already satisfied: cryptography>=36.0.0 in c:\ai\envs\ai\lib\site-packages (from pdfminer.six==20251230->pdfplumber) (46.0.5)
# Requirement already satisfied: cffi>=2.0.0 in c:\ai\envs\ai\lib\site-packages (from cryptography>=36.0.0->pdfminer.six==20251230->pdfplumber) (2.0.0)
# Requirement already satisfied: typing-extensions>=4.13.2 in c:\ai\envs\ai\lib\site-packages (from cryptography>=36.0.0->pdfminer.six==20251230->pdfplumber) (4.15.0)
# Requirement already satisfied: pycparser in c:\ai\envs\ai\lib\site-packages (from cffi>=2.0.0->cryptography>=36.0.0->pdfminer.six==20251230->pdfplumber) (3.0)
# Downloading pdfplumber-0.11.9-py3-none-any.whl (60 kB)
# Downloading pdfminer_six-20251230-py3-none-any.whl (6.6 MB)
#    ---------------------------------------- 0.0/6.6 MB ? eta -:--:--
#    ---------------------------------- ----- 5.8/6.6 MB 29.4 MB/s eta 0:00:01
#    ---------------------------------------- 6.6/6.6 MB 25.3 MB/s  0:00:00
# Installing collected packages: pdfminer.six, pdfplumber
#
#   Attempting uninstall: pdfminer.six
#
#     Found existing installation: pdfminer.six 20260107
#
#     Uninstalling pdfminer.six-20260107:
#
#       Successfully uninstalled pdfminer.six-20260107
#
#    ---------------------------------------- 0/2 [pdfminer.six]
#    ---------------------------------------- 0/2 [pdfminer.six]
#    ---------------------------------------- 0/2 [pdfminer.six]
#    ---------------------------------------- 0/2 [pdfminer.six]
#    -------------------- ------------------- 1/2 [pdfplumber]
#    -------------------- ------------------- 1/2 [pdfplumber]
#    -------------------- ------------------- 1/2 [pdfplumber]
#    -------------------- ------------------- 1/2 [pdfplumber]
#    -------------------- ------------------- 1/2 [pdfplumber]
#    -------------------- ------------------- 1/2 [pdfplumber]
#    -------------------- ------------------- 1/2 [pdfplumber]
#    -------------------- ------------------- 1/2 [pdfplumber]
#    -------------------- ------------------- 1/2 [pdfplumber]
#    -------------------- ------------------- 1/2 [pdfplumber]
#    ---------------------------------------- 2/2 [pdfplumber]
#
# Successfully installed pdfminer.six-20251230 pdfplumber-0.11.9
# WARNING: Ignoring invalid distribution -ensorflow (c:\ai\envs\ai\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (c:\ai\envs\ai\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (c:\ai\envs\ai\lib\site-packages)

# %%
from langchain_community.document_loaders import PDFPlumberLoader

# PDF 문서 로더 인스턴스 생성
loader = PDFPlumberLoader(FILE_PATH)

# 문서 로딩
docs = loader.load()

# 첫 번째 문서 데이터 접근
print(docs[0].page_content[:300])
# Out:
# 12
# 2023년 월호

# %%
show_metadata(docs)
# Out:
# [metadata]
# ['source', 'file_path', 'page', 'total_pages', 'Author', 'Creator', 'Producer', 'CreationDate', 'ModDate', 'PDFVersion']
#
# [examples]
# source       : ./data/SPRI_AI_Brief_2023년12월호_F.pdf
# file_path    : ./data/SPRI_AI_Brief_2023년12월호_F.pdf
# page         : 0
# total_pages  : 23
# Author       : dj
# Creator      : Hwp 2018 10.0.0.13462
# Producer     : Hancom PDF 1.3.0.542
# CreationDate : D:20231208132838+09'00'
# ModDate      : D:20231208132838+09'00'
# PDFVersion   : 1.4
